# %%
import pandas as pd
import numpy as np

train = pd.read_csv("train.csv")

train.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#    DayOfWeek PdDistrict      Resolution                    Address  \
# 0  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 1  Wednesday   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST
# 2  Wednesday   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST
# 3  Wednesday   NORTHERN            NONE   1500 Block of LOMBARD ST
# 4  Wednesday       PARK            NONE  100 Block of BRODERICK ST
#
#             X          Y
# 0 -122.425892  37.774599
# 1 -122.425892  37.774599
# 2 -122.424363  37.800414
# 3 -122.426995  37.800873
# 4 -122.438738  37.771541

# %%
train = train[np.abs(train.X-train.X.mean())<=(3*train.X.std())]
train = train[np.abs(train.Y-train.Y.mean())<=(3*train.Y.std())]

# %%
dow = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
for i in xrange(len(dow)):
    train.DayOfWeek[train["DayOfWeek"] == dow[i]] = i

train.head()
# Out:
# /home/jsutker/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#   DayOfWeek PdDistrict      Resolution                    Address           X  \
# 0         2   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892
# 1         2   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892
# 2         2   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST -122.424363
# 3         2   NORTHERN            NONE   1500 Block of LOMBARD ST -122.426995
# 4         2       PARK            NONE  100 Block of BRODERICK ST -122.438738
#
#            Y
# 0  37.774599
# 1  37.774599
# 2  37.800414
# 3  37.800873
# 4  37.771541

# %%
def parse_date(datetime):
    """ Convert a date in YYYY-MM-DD HH:MM:SS to a tuple
        containing year, month, day, and hours each expressed
        as an integer.

        >>> parse_date("2014-04-05 14:00:00")
        (2014, 4, 5, 14)
    """
    # Taken from bikeshare notebook from day02
    return int(datetime[0:4]), int(datetime[5:7]), int(datetime[8:10]), int(datetime[11:13])

years = []
months = []
days = []
hours = []
for d in train.Dates:
    year, month, day, hour = parse_date(d)
    years.append(year)
    months.append(month)
    days.append(day)
    hours.append(hour)
train["Year"] = years
train["Month"] = months
train["Day"] = days
train["Hour"] = hours

train.head()
# Out:
#                  Dates        Category                      Descript  \
# 0  2015-05-13 23:53:00        WARRANTS                WARRANT ARREST
# 1  2015-05-13 23:53:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 2  2015-05-13 23:33:00  OTHER OFFENSES      TRAFFIC VIOLATION ARREST
# 3  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
# 4  2015-05-13 23:30:00   LARCENY/THEFT  GRAND THEFT FROM LOCKED AUTO
#
#   DayOfWeek PdDistrict      Resolution                    Address           X  \
# 0         2   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892
# 1         2   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892
# 2         2   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST -122.424363
# 3         2   NORTHERN            NONE   1500 Block of LOMBARD ST -122.426995
# 4         2       PARK            NONE  100 Block of BRODERICK ST -122.438738
#
#            Y  Year  Month  Day  Hour
# 0  37.774599  2015      5   13    23
# 1  37.774599  2015      5   13    23
# 2  37.800414  2015      5   13    23
# 3  37.800873  2015      5   13    23
# 4  37.771541  2015      5   13    23

# %%
cats = train["Category"].unique()
for i in xrange(len(cats)):
    train.Category[train["Category"] == cats[i]] = i
train.head()
# Out:
# /home/jsutker/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   app.launch_new_instance()
#                  Dates Category                      Descript DayOfWeek  \
# 0  2015-05-13 23:53:00        0                WARRANT ARREST         2
# 1  2015-05-13 23:53:00        1      TRAFFIC VIOLATION ARREST         2
# 2  2015-05-13 23:33:00        1      TRAFFIC VIOLATION ARREST         2
# 3  2015-05-13 23:30:00        2  GRAND THEFT FROM LOCKED AUTO         2
# 4  2015-05-13 23:30:00        2  GRAND THEFT FROM LOCKED AUTO         2
#
#   PdDistrict      Resolution                    Address           X  \
# 0   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892
# 1   NORTHERN  ARREST, BOOKED         OAK ST / LAGUNA ST -122.425892
# 2   NORTHERN  ARREST, BOOKED  VANNESS AV / GREENWICH ST -122.424363
# 3   NORTHERN            NONE   1500 Block of LOMBARD ST -122.426995
# 4       PARK            NONE  100 Block of BRODERICK ST -122.438738
#
#            Y  Year  Month  Day  Hour
# 0  37.774599  2015      5   13    23
# 1  37.774599  2015      5   13    23
# 2  37.800414  2015      5   13    23
# 3  37.800873  2015      5   13    23
# 4  37.771541  2015      5   13    23

# %%
# Import the linear regression class
from sklearn.linear_model import LinearRegression

# Sklearn also has a helper that makes it easy to do cross validation
from sklearn.cross_validation import KFold

predictors = ["DayOfWeek","X","Y","Year","Month","Day","Hour"]

alg = LinearRegression()

kf = KFold(train.shape[0], n_folds=3, random_state=1)

predictions = []
for tr, te in kf:
    # The predictors we're using the train the algorithm.  Note how we only take the rows in the train folds.
    train_predictors = (train[predictors].iloc[tr,:])
    # The target we're using to train the algorithm.
    train_target = train["Category"].iloc[tr]
    # Training the algorithm using the predictors and target.
    alg.fit(train_predictors, train_target)
    # We can now make predictions on the test fold
    test_predictions = alg.predict(train[predictors].iloc[te,:])
    predictions.append(test_predictions)
predictions = np.concatenate(predictions, axis=0)

# %%
for i in xrange(len(predictions)):
    predictions[i] = int(predictions[i])
accuracy = len(predictions[predictions == train["Category"]])/len(predictions)
print predictions
print train["Category"]
# Out:
# [ 7.  7.  6. ...,  8.  8.  9.]
# 0          0
# 1          1
# 2          1
# 3          2
# 4          2
# 5          2
# 6          3
# 7          3
# 8          2
# 9          2
# 10         2
# 11         1
# 12         4
# 13         2
# 14         5
# 15         5
# 16         6
# 17         7
# 18         1
# 19         5
# 20         2
# 21         6
# 22         0
# 23         5
# 24         2
# 25         5
# 26         2
# 27         2
# 28         2
# 29         1
#           ..
# 878019     1
# 878020     1
# 878021     4
# 878022     3
# 878023     2
# 878024     1
# 878025     1
# 878026     0
# 878027     0
# 878028     7
# 878029     1
# 878030    22
# 878031     7
# 878032     1
# 878033     4
# 878034    16
# 878035     7
# 878036     2
# 878037     4
# 878038     0
# 878039     1
# 878040     7
# 878041     1
# 878042     7
# 878043     1
# 878044     6
# 878045     2
# 878046     2
# 878047     4
# 878048    12
# Name: Category, dtype: object
# /home/jsutker/anaconda2/lib/python2.7/site-packages/ipykernel/__main__.py:3: FutureWarning: in the future, boolean array-likes will be handled as a boolean array index
#   app.launch_new_instance()
